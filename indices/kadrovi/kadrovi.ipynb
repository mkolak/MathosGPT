# %%
import os
os.environ["OPENAI_API_KEY"] = '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'

# %%
from llama_index import VectorStoreIndex, SimpleDirectoryReader
from llama_index.node_parser import SimpleNodeParser
from llama_index.indices.service_context import ServiceContext
from llama_index import StorageContext, load_index_from_storage
from llama_index.llms import OpenAI

from llama_index.schema import TextNode, NodeRelationship, RelatedNodeInfo

# %% [markdown]
# # Building knowledge base with nodes

# %% [markdown]
# ## Adding Nastavnici i suradnici

# %%
nastavnici_suradnici_osoblje = SimpleDirectoryReader('data/nastavnici i suradnici', filename_as_id=True).load_data()

# %%
def dissolve_employees_into_nodes(document):
    filename = os.path.splitext(os.path.basename(document.id_))[0]

    nodes = []
    root_node_text = ""
    root_text = document.text
    root_node = TextNode(
        text='',
        metadata={
            'filename': filename,
            'type': 'list'
        },
        id_=filename
    )
    child_node_texts = root_text.split('\n\n\n')
    for cn_text in child_node_texts:
        name = cn_text.split('\n')[0]
        node = TextNode(text=cn_text, 
                        metadata={
                            'name': name,
                            'type': 'Personal details'
                        },
                        id_=name
                       )
        node.relationships[NodeRelationship.PREVIOUS] = RelatedNodeInfo(node_id=root_node.id_)
        nodes.append(node)
        root_node_text += name + '\n'
    root_node.text = root_node_text
    nodes = [root_node] + nodes
    return nodes

# %%
nodes = []
for doc in nastavnici_suradnici_osoblje:
    nodes += dissolve_employees_into_nodes(doc)

# %% [markdown]
# ### Obrada profila nastavnika

# %%
profili_nastavnika = SimpleDirectoryReader('data/nastavnici i suradnici/profili', filename_as_id=True).load_data()

# %%
def handle_profile(document, existing_nodes):
    name = os.path.splitext(os.path.basename(document.id_))[0]
    nodes_section = []
    root_text = document.text
    child_node_texts = root_text.split('\n\n\n')
    for cn_text in child_node_texts:
        section = cn_text.split('\n')[0]
        new_id = name + ' ' + section
        node = TextNode(text=cn_text, 
                        metadata={
                            'name': name,
                            'type': 'Additional information',
                            'section': section
                        },
                        id_= new_id
                       )
        node.relationships[NodeRelationship.PREVIOUS] = RelatedNodeInfo(node_id=name)
        
        for elem in existing_nodes:
            if elem.id_ == name:
                elem.relationships[NodeRelationship.NEXT] = RelatedNodeInfo(node_id=new_id) 
                
        nodes_section.append(node)
    return nodes_section

# %%
profile_nodes = []
for profile in profili_nastavnika:
    profile_nodes += handle_profile(profile, nodes)

# %%
nodes += profile_nodes

# %%
for i, node in enumerate(nodes):
    print(i, ', len: ', len(node.text))
# Out:
# 0 , len:  176
# 1 , len:  172
# 2 , len:  114
# 3 , len:  150
# 4 , len:  129
# 5 , len:  216
# 6 , len:  133
# 7 , len:  147
# 8 , len:  337
# 9 , len:  130
# 10 , len:  183
# 11 , len:  160
# 12 , len:  81
# 13 , len:  93
# 14 , len:  197
# 15 , len:  193
# 16 , len:  177
# 17 , len:  815
# 18 , len:  811
# 19 , len:  344
# 20 , len:  352
# 21 , len:  322
# 22 , len:  395
# 23 , len:  324
# 24 , len:  325
# 25 , len:  332
# 26 , len:  318
# 27 , len:  323
# 28 , len:  371
# 29 , len:  314
# 30 , len:  325
# 31 , len:  319
# 32 , len:  330
# 33 , len:  329
# 34 , len:  321
# 35 , len:  326
# 36 , len:  333
# 37 , len:  310
# 38 , len:  314
# 39 , len:  337
# 40 , len:  327
# 41 , len:  381
# 42 , len:  568
# 43 , len:  181
# 44 , len:  53
# 45 , len:  77
# 46 , len:  98
# 47 , len:  82
# 48 , len:  81
# 49 , len:  50
# 50 , len:  26
# 51 , len:  75
# 52 , len:  49
# 53 , len:  109
# 54 , len:  76
# 55 , len:  205
# 56 , len:  83
# 57 , len:  85
# 58 , len:  79
# 59 , len:  112
# 60 , len:  78
# 61 , len:  38
# 62 , len:  79
# 63 , len:  80
# 64 , len:  300
# 65 , len:  237
# 66 , len:  286
# 67 , len:  293
# 68 , len:  337
# 69 , len:  316
# 70 , len:  327
# 71 , len:  245
# 72 , len:  317
# 73 , len:  328
# 74 , len:  225
# 75 , len:  282
# 76 , len:  335
# 77 , len:  224
# 78 , len:  336
# 79 , len:  326
# 80 , len:  106
# 81 , len:  12
# 82 , len:  101
# 83 , len:  96
# 84 , len:  87
# 85 , len:  168
# 86 , len:  533
# 87 , len:  851
# 88 , len:  1073
# 89 , len:  31
# 90 , len:  600
# 91 , len:  307
# 92 , len:  48
# 93 , len:  31
# 94 , len:  2070
# 95 , len:  3529
# 96 , len:  797
# 97 , len:  3390
# 98 , len:  622
# 99 , len:  699
# 100 , len:  1417
# 101 , len:  2575
# 102 , len:  1254
# 103 , len:  289
# 104 , len:  2318
# 105 , len:  2077
# 106 , len:  611
# 107 , len:  4150
# 108 , len:  990
# 109 , len:  4637
# 110 , len:  1912
# 111 , len:  28
# 112 , len:  567
# 113 , len:  2777
# 114 , len:  829
# 115 , len:  721
# 116 , len:  2259
# 117 , len:  4709
# 118 , len:  2449
# 119 , len:  48
# 120 , len:  1208
# 121 , len:  2290
# 122 , len:  206
# 123 , len:  512
# 124 , len:  648
# 125 , len:  1358
# 126 , len:  1662
# 127 , len:  3981
# 128 , len:  1414
# 129 , len:  654
# 130 , len:  371
# 131 , len:  864
# 132 , len:  739
# 133 , len:  1018
# 134 , len:  2271
# 135 , len:  1190
# 136 , len:  714
# 137 , len:  1259
# 138 , len:  890
# 139 , len:  4191
# 140 , len:  901
# 141 , len:  96
# 142 , len:  1067
# 143 , len:  1712
# 144 , len:  1397
# 145 , len:  3490
# 146 , len:  1043
# 147 , len:  71
# 148 , len:  842
# 149 , len:  2909
# 150 , len:  738
# 151 , len:  651
# 152 , len:  858
# 153 , len:  1339
# 154 , len:  1141
# 155 , len:  4732
# 156 , len:  1986
# 157 , len:  659
# 158 , len:  2369
# 159 , len:  670
# 160 , len:  2382
# 161 , len:  925
# 162 , len:  1092
# 163 , len:  2392
# 164 , len:  459
# 165 , len:  747
# 166 , len:  220
# 167 , len:  46
# 168 , len:  636
# 169 , len:  2227
# 170 , len:  455
# 171 , len:  1658
# 172 , len:  1279
# 173 , len:  1472
# 174 , len:  6062
# 175 , len:  1051
# 176 , len:  454
# 177 , len:  1385
# 178 , len:  813
# 179 , len:  4062
# 180 , len:  720
# 181 , len:  3254
# 182 , len:  1715
# 183 , len:  94
# 184 , len:  1143
# 185 , len:  7989
# 186 , len:  2830
# 187 , len:  1073
# 188 , len:  1342
# 189 , len:  707
# 190 , len:  9671
# 191 , len:  734
# 192 , len:  2106
# 193 , len:  826
# 194 , len:  119
# 195 , len:  641
# 196 , len:  3623
# 197 , len:  2876
# 198 , len:  322
# 199 , len:  670
# 200 , len:  836
# 201 , len:  806
# 202 , len:  873
# 203 , len:  6041
# 204 , len:  4767
# 205 , len:  4544
# 206 , len:  1198
# 207 , len:  2142
# 208 , len:  4312
# 209 , len:  507
# 210 , len:  134
# 211 , len:  684
# 212 , len:  2814
# 213 , len:  1076
# 214 , len:  2931
# 215 , len:  1280
# 216 , len:  7603
# 217 , len:  3114
# 218 , len:  3136
# 219 , len:  8218
# 220 , len:  2051
# 221 , len:  779
# 222 , len:  4074
# 223 , len:  732
# 224 , len:  3395
# 225 , len:  773
# 226 , len:  90
# 227 , len:  561
# 228 , len:  5515
# 229 , len:  899
# 230 , len:  234
# 231 , len:  719
# 232 , len:  698
# 233 , len:  6914
# 234 , len:  2598
# 235 , len:  10337
# 236 , len:  5369
# 237 , len:  1674
# 238 , len:  619
# 239 , len:  1405
# 240 , len:  225
# 241 , len:  60
# 242 , len:  536
# 243 , len:  190
# 244 , len:  432
# 245 , len:  729
# 246 , len:  9121
# 247 , len:  3655
# 248 , len:  1098
# 249 , len:  1198
# 250 , len:  1693
# 251 , len:  2709
# 252 , len:  580
# 253 , len:  140
# 254 , len:  780
# 255 , len:  6342
# 256 , len:  5115
# 257 , len:  857
# 258 , len:  353
# 259 , len:  1484
# 260 , len:  993
# 261 , len:  6589
# 262 , len:  3418
# 263 , len:  8570
# 264 , len:  2454
# 265 , len:  211
# 266 , len:  949
# 267 , len:  11035
# 268 , len:  4467
# 269 , len:  699
# 270 , len:  2606
# 271 , len:  1643
# 272 , len:  142
# 273 , len:  714
# 274 , len:  502
# 275 , len:  5516
# 276 , len:  727
# 277 , len:  1639
# 278 , len:  1326
# 279 , len:  124
# 280 , len:  3635
# 281 , len:  6142
# 282 , len:  3774
# 283 , len:  5146
# 284 , len:  2548
# 285 , len:  2714
# 286 , len:  2615
# 287 , len:  484
# 288 , len:  286
# 289 , len:  762
# 290 , len:  728
# 291 , len:  7598
# 292 , len:  3322
# 293 , len:  1963
# 294 , len:  3369
# 295 , len:  730
# 296 , len:  184
# 297 , len:  1601
# 298 , len:  6617
# 299 , len:  7198
# 300 , len:  7374
# 301 , len:  5695
# 302 , len:  7450
# 303 , len:  5365
# 304 , len:  1518
# 305 , len:  4649
# 306 , len:  327
# 307 , len:  604
# 308 , len:  7141
# 309 , len:  1805
# 310 , len:  620
# 311 , len:  743
# 312 , len:  701
# 313 , len:  156
# 314 , len:  458
# 315 , len:  561
# 316 , len:  56
# 317 , len:  32
# 318 , len:  557
# 319 , len:  4056
# 320 , len:  624

# %% [markdown]
# ## Ispitivanje modela

# %%
index = VectorStoreIndex(nodes,show_progress=True)
# Out:
# Generating embeddings:   0%|                                                                   | 0/321 [00:00<?, ?it/s]
# Generating embeddings:   3%|█▊                                                        | 10/321 [00:00<00:21, 14.47it/s]
# Generating embeddings:   6%|███▌                                                      | 20/321 [00:01<00:19, 15.63it/s]
# Generating embeddings:   9%|█████▍                                                    | 30/321 [00:01<00:17, 16.18it/s]
# Generating embeddings:  12%|███████▏                                                  | 40/321 [00:02<00:18, 15.51it/s]
# Generating embeddings:  16%|█████████                                                 | 50/321 [00:03<00:16, 16.32it/s]
# Generating embeddings:  19%|██████████▊                                               | 60/321 [00:03<00:16, 16.30it/s]
# Generating embeddings:  22%|████████████▋                                             | 70/321 [00:04<00:15, 16.30it/s]
# Generating embeddings:  25%|██████████████▍                                           | 80/321 [00:04<00:14, 17.07it/s]
# Generating embeddings:  28%|████████████████▎                                         | 90/321 [00:05<00:13, 16.83it/s]
# Generating embeddings:  31%|█████████████████▊                                       | 100/321 [00:06<00:17, 12.69it/s]
# Generating embeddings:  34%|███████████████████▌                                     | 110/321 [00:07<00:16, 13.05it/s]
# Generating embeddings:  37%|█████████████████████▎                                   | 120/321 [00:08<00:14, 13.55it/s]
# Generating embeddings:  40%|███████████████████████                                  | 130/321 [00:08<00:13, 14.37it/s]
# Generating embeddings:  44%|████████████████████████▊                                | 140/321 [00:09<00:12, 14.78it/s]
# Generating embeddings:  47%|██████████████████████████▋                              | 150/321 [00:09<00:11, 15.30it/s]
# Generating embeddings:  50%|████████████████████████████▍                            | 160/321 [00:10<00:10, 15.26it/s]
# Generating embeddings:  53%|██████████████████████████████▏                          | 170/321 [00:11<00:09, 15.86it/s]
# Generating embeddings:  56%|███████████████████████████████▉                         | 180/321 [00:11<00:09, 15.32it/s]
# Generating embeddings:  59%|█████████████████████████████████▋                       | 190/321 [00:12<00:08, 14.93it/s]
# Generating embeddings:  62%|███████████████████████████████████▌                     | 200/321 [00:13<00:08, 13.53it/s]
# Generating embeddings:  65%|█████████████████████████████████████▎                   | 210/321 [00:14<00:07, 14.05it/s]
# Generating embeddings:  69%|███████████████████████████████████████                  | 220/321 [00:14<00:07, 13.75it/s]
# Generating embeddings:  72%|████████████████████████████████████████▊                | 230/321 [00:15<00:06, 14.27it/s]
# Generating embeddings:  75%|██████████████████████████████████████████▌              | 240/321 [00:16<00:05, 13.97it/s]
# Generating embeddings:  78%|████████████████████████████████████████████▍            | 250/321 [00:17<00:05, 13.51it/s]
# Generating embeddings:  81%|██████████████████████████████████████████████▏          | 260/321 [00:17<00:04, 13.80it/s]
# Generating embeddings:  84%|███████████████████████████████████████████████▉         | 270/321 [00:18<00:03, 12.78it/s]
# Generating embeddings:  87%|█████████████████████████████████████████████████▋       | 280/321 [00:19<00:02, 13.68it/s]
# Generating embeddings:  90%|███████████████████████████████████████████████████▍     | 290/321 [00:20<00:02, 12.84it/s]
# Generating embeddings:  93%|█████████████████████████████████████████████████████▎   | 300/321 [00:20<00:01, 13.33it/s]
# Generating embeddings:  97%|███████████████████████████████████████████████████████  | 310/321 [00:21<00:00, 13.44it/s]
# Generating embeddings: 100%|█████████████████████████████████████████████████████████| 321/321 [00:22<00:00, 14.08it/s]

# %%
index.storage_context.persist()

# %%
llm = OpenAI(model="gpt-3.5-turbo", temperature=0, max_tokens=2048)
service_context = ServiceContext.from_defaults(llm=llm)
query_engine = index.as_query_engine(service_context=service_context)

# %%
response = query_engine.query("What are some of the publications that Domagoj Matijevic has taken part in?")
print(response)
# Out:
# Some of the publications that Domagoj Matijević has taken part in are:
#
# 1. "Efficient Implementations of Guarding 1.5D Terrains" in Croatian Operational Research Review 6/1 (2015), 79-89.
# 2. "Guarding 1.5D Terrains with Demands" in International Journal of Computer Mathematics 89/16 (2012), 2143-2151.
# 3. "Improved Approximations for Guarding 1.5-Dimensional Terrains" in Algorithmica 60/2 (2011), 451-463.
# 4. "Naive Matrix Multiplication versus Strassen Algorithm in Multi-thread Environment" in Tehnički vjesnik 18/3 (2011), 309-314.
# 5. "Compressing Sentence Representation with Maximum Coding Rate Reduction" in ICT and Electronics Convention (MIPRO), 2023 46th MIPRO, Opatija, Hrvatska, 2023.
# 6. "Fortuna Detects Novel Splicing in Drosophila scRNASeq Data" in ICT and Electronics Convention (MIPRO), 2023 46th MIPRO, Opatija, Hrvatska, 2023, 410-415.
# 7. "Uparena optimizacijska metoda" in Math.e : hrvatski matematički elektronski časopis 30 (2016).
# 8. "Grčko - kineski stil u teoriji brojeva" in Osječki matematički list 10/1 (2010), 43-58.
# 9. "Metodički aspekti abakusa II" in Matematika i škola 53 (2010), 106-111.
# 10. "Problem vidljivosti" in Osječki matematički list (2010), prihvaćen za objavljivanje.
# 11. "Metodički aspekti abakusa I" in Matematika i škola 52 (2009), 57-62.
# 12. "Numerička ograničenja kineskog abakusa" in Osječki matematički list 9 (2009), 75-91.
#
# Additionally, Domagoj Matijević has also taken part in the following publications:
#
# 1. Geometric Optimization and Querying -- Exact and Approximate (1.3MB) Thesis for obtaining the degree of a Doctor of the Engineering Sciences (Dr.-Ing.) of the natural-technical faculties of Saarland University, Saarbrücken, 2007.
# 2. MS in CS, Saarland University, Germany, 2002.
# 3. BS in Mathematics and Computer Science, Department of Mathematics, University of Osijek, Croatia, 2001.

# %%
parser = SimpleNodeParser()
nodes = parser.get_nodes_from_documents(documents)
